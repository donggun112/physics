# %% [markdown]
# <a href="https://colab.research.google.com/github/donggun112/physics/blob/20250406/%EA%B1%B4%EB%AC%BC_%EC%98%A5%EC%83%81%EC%97%90%EC%84%9C_%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99_%ED%8C%8C%EC%9D%B4%EC%8D%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# 사용자 입력
t = float(input("공이 떨어지기까지 걸린 시간(s)을 입력하세요: "))
x = float(input("수평 거리(m)를 입력하세요: "))

# 중력가속도 (음의 방향으로 작용)
g = -9.81

# 초기 위치와 수직 방향 속도
y0 = 0
v0y = 0

# a) 공의 수평 방향 초기 속도 계산
v0x = x / t

# b) 건물의 높이 계산: y = y0 + v0y*t + 1/2 * g * t^2
y = y0 + v0y * t + 0.5 * g * t**2

# c) 공의 충돌 순간 속도 (벡터 합)
vx = v0x
vy = v0y + g * t
v = math.sqrt(vx**2 + vy**2)

# 속도 방향(수평선과의 각도)
theta_rad = math.atan2(vy, vx)
theta_deg = math.degrees(theta_rad)

# 결과 출력
print(f"\n[결과]")
print(f"a) 공의 수평 방향 처음 속도: {v0x:.2f} m/s")
print(f"b) 건물 높이: {abs(y):.2f} m")  # 절댓값으로 표시
print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")
print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")
# Out:
# 공이 떨어지기까지 걸린 시간(s)을 입력하세요: 5
# 수평 거리(m)를 입력하세요: 23
#
# [결과]
# a) 공의 수평 방향 처음 속도: 4.60 m/s
# b) 건물 높이: 122.62 m
# c) 충돌 순간 속도 크기: 49.27 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): -84.64도
