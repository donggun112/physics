# %% [markdown]
# <a href="https://colab.research.google.com/github/donggun112/physics/blob/20250331/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B2%A1%ED%84%B0_%ED%95%A9%EA%B3%BC_%EB%82%B4%EC%A0%81%2C_%EC%99%B8%EC%A0%81_%EA%B3%84%EC%82%B0%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2차원 벡터 연산

# 첫 번째 벡터 입력 받기
x1 = float(input("첫 번째 벡터의 x성분을 입력하세요:"))
y1 = float(input("첫 번째 벡터의 y성분을 입력하세요:"))

# 두번쨰 벡터 입력 받기
x2 = float(input("두 번째 벡터의 x성분을 입력하세요:"))
y2 = float(input("두 번째 벡터의 y성분을 입력하세요:"))

# 벡터의 합 계산
sum_x = x1 + x2
sum_y = y1 + y2

# 벡터의 내적 계산 (dot product)
dot_product = x1 * x2 + y1 * y2

# 벡터의 외적 계산 (cross product)
# 2차원 벡터의 외적은 스칼라 값으로, z축 방향의 크기를 나타냅니다.
cross_product = x1 * y2 - y1 * x2

# 결과 출력
print("\n벡터 1:", x1, "i +", y1, "j")
print("벡터2:", x2, "he i +", y2, "j")
print("\n벡터의 합:", sum_x, "i +", sum_y, "j")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x성분을 입력하세요:2
# 첫 번째 벡터의 y성분을 입력하세요:1
# 두 번째 벡터의 x성분을 입력하세요:1
# 두 번째 벡터의 y성분을 입력하세요:2
#
# 벡터 1: 2.0 i + 1.0 j
# 벡터2: 1.0 i + 2.0 j
#
# 벡터의 합: 3.0 i + 3.0 j
# 벡터의 내적: 4.0
# 벡터의 외적: 3.0
